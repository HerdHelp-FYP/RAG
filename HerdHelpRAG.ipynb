# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/generation/llm-field-guide/llama-2/llama-2-13b-retrievalqa.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/generation/llm-field-guide/llama-2/llama-2-13b-retrievalqa.ipynb)
#
# # RAG with LLaMa 13B
#
# In this notebook we'll explore how we can use the open source **Llama-13b-chat** model in both Hugging Face transformers and LangChain.
# At the time of writing, you must first request access to Llama 2 models via [this form](https://ai.meta.com/resources/models-and-libraries/llama-downloads/) (access is typically granted within a few hours). If you need guidance on getting access please refer to the beginning of this [article](https://www.pinecone.io/learn/llama-2/) or [video](https://youtu.be/6iHVJyX2e50?t=175).
#
# ---
#
# 🚨 _Note that running this on CPU is sloooow. If running on Google Colab you can avoid this by going to **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**. This should be included within the free tier of Colab._
#
# ---
#
# We start by doing a `pip install` of all required libraries.

# %%
# !pip install -qU \
  transformers==4.31.0 \
  sentence-transformers==2.2.2 \
  pinecone-client==2.2.2 \
  datasets==2.14.0 \
  accelerate==0.21.0 \
  einops==0.6.1 \
  langchain==0.0.240 \
  xformers==0.0.20 \
  bitsandbytes==0.41.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 kB 46.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 3.9 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for lit (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.

# %% [markdown]
# ## Initializing the Hugging Face Embedding Pipeline
#
# We begin by initializing the embedding pipeline that will handle the transformation of our docs into vector embeddings. We will use the `sentence-transformers/all-MiniLM-L6-v2` model for embedding.

# %%
from torch import cuda
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

embed_model = HuggingFaceEmbeddings(
    model_name=embed_model_id,
    model_kwargs={'device': device},
    encode_kwargs={'device': device, 'batch_size': 50}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# We can use the embedding model to create document embeddings like so:

# %%
docs = [
    "this is one document",
    "and another document"
]

embeddings = embed_model.embed_documents(docs)

print(f"We have {len(embeddings)} doc embeddings, each with "
      f"a dimensionality of {len(embeddings[0])}.")
# Out:
# We have 2 doc embeddings, each with a dimensionality of 384.

# %% [markdown]
# ## Building the Vector Index
#
# We now need to use the embedding pipeline to build our embeddings and store them in a Pinecone vector index. To begin we'll initialize our index, for this we'll need a [free Pinecone API key](https://app.pinecone.io/).

# %%
import os
import pinecone

# get API key from app.pinecone.io and environment from console
pinecone.init(
    api_key=os.environ.get('YOUR KEY') or 'YOUR KEY',
    environment=os.environ.get('gcp-starter') or 'gcp-starter'
)

# %% [markdown]
# Now we initialize the index.

# %%
import time

index_name = 'YOUR INDEX NAME'

if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        index_name,
        dimension=len(embeddings[0]),
        metric='cosine'
    )
    # wait for index to finish initialization
    while not pinecone.describe_index(index_name).status['ready']:
        time.sleep(1)

# %% [markdown]
# Now we connect to the index:

# %%
index = pinecone.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# We will embed and index the documents like so:

# %%
from datasets import load_dataset

data = load_dataset("json", data_files="mudata.json", split='train')
data
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['answer', 'question'],
#     num_rows: 4161
# })

# %%
import json
import csv

# Read the original JSON file
json_file_path = 'mudata.json'
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

# Add IDs to each row
for idx, row in enumerate(data, start=1):
    row['id'] = idx

# Write the updated data to a new CSV file
new_csv_file_path = 'data.csv'
fieldnames = data[0].keys() if data else []  # Assuming the JSON has a list of dictionaries with the same keys
with open(new_csv_file_path, 'w', newline='') as new_csv_file:
    csv_writer = csv.DictWriter(new_csv_file, fieldnames=fieldnames)
    csv_writer.writeheader()
    csv_writer.writerows(data)

print(f'Updated data with IDs written to {new_csv_file_path}')
# Out:
# Updated data with IDs written to data.csv

# %%
from datasets import load_dataset

data = load_dataset("csv", data_files="data.csv", split='train')
data
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['question', 'answer', 'id'],
#     num_rows: 4161
# })

# %%
data = data.to_pandas()

batch_size = 50

for i in range(0, len(data), batch_size):
    i_end = min(len(data), i+batch_size)
    batch = data.iloc[i:i_end]
    ids = [f"{x['id']}" for i, x in batch.iterrows()]

    # Include both 'question' and 'answer' in the 'texts' list
    texts = [f"{x['question']} {x['answer']}" for i, x in batch.iterrows()]

    embeds = embed_model.embed_documents(texts)

    # Replace 'story' with both 'question' and 'answer' in the metadata
    metadata = [
        {'text': f"{x['question']} {x['answer']}",
         'title': x['id']} for i, x in batch.iterrows()
    ]

    # add to Pinecone
    index.upsert(vectors=zip(ids, embeds, metadata))

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0235,
#  'namespaces': {'': {'vector_count': 2350}},
#  'total_vector_count': 2350}

# %% [markdown]
# ## Initializing the Hugging Face Pipeline

# %% [markdown]
# The first thing we need to do is initialize a `text-generation` pipeline with Hugging Face transformers. The Pipeline requires three things that we must initialize first, those are:
#
# * A LLM, in this case it will be `meta-llama/Llama-2-13b-chat-hf`.
#
# * The respective tokenizer for the model.
#
# We'll explain these as we get to them, let's begin with our model.
#
# We initialize the model and move it to our CUDA-enabled GPU. Using Colab this can take 5-10 minutes to download and initialize the model.

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
hf_auth = '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'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)
model.eval()
print(f"Model loaded on {device}")
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0

# %% [markdown]
# The pipeline requires a tokenizer which handles the translation of human readable plaintext to LLM readable token IDs. The Llama 2 13B models were trained using the Llama 2 13B tokenizer, which we initialize like so:

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# Now we're ready to initialize the HF pipeline. There are a few additional parameters that we must define here. Comments explaining these have been included in the code.

# %%
generate_text = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    temperature=0.0,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=512,  # mex number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)

# %% [markdown]
# Confirm this is working:

# %%
res = generate_text("Explain to me the difference between nuclear fission and fusion.")
print(res[0]["generated_text"])
# Out:
# Explain to me the difference between nuclear fission and fusion. Unterscheidung zwischen Nuklearfusion und -fission.
# Nuclear fission is a process in which an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. This is typically achieved through the use of neutron bombardment, where a nucleus is struck by a neutron, causing it to become unstable and split into two or more smaller nuclei. Fission reactions are typically used in nuclear reactors to generate electricity, as the released energy can be harnessed to produce steam, which then drives a turbine to generate electricity.
# Nuclear fusion, on the other hand, is the process by which two or more atomic nuclei combine to form a single, heavier nucleus. This process also releases energy, but in this case, the energy is produced through the binding of the nuclei together. Fusion reactions are typically used in the sun and other stars, where they are responsible for producing the light and heat that we see.
# The main difference between nuclear fission and fusion is the direction of the energy release. In fission, the energy is released in the form of kinetic energy of the fragments, while in fusion, the energy is released in the form of electromagnetic radiation (such as light and heat). Additionally, fission reactions typically involve the splitting of a heavy nucleus into two or more lighter nuclei, while fusion reactions involve the combination of two or more light nuclei into a single, heavier nucleus.
# In summary, nuclear fission is the process of splitting a heavy nucleus into two or more lighter nuclei, releasing energy in the process, while nuclear fusion is the process of combining two or more light nuclei into a single, heavier nucleus, also releasing energy.

# %% [markdown]
# Now to implement this in LangChain

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
llm(prompt="Explain to me the difference between nuclear fission and fusion.")
# Out:
# ' Unterscheidung zwischen Nuklearfusion und -fission.\nNuclear fission is a process in which an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. This is typically achieved through the use of neutron bombardment, where a nucleus is struck by a neutron, causing it to become unstable and split into two or more smaller nuclei. Fission reactions are typically used in nuclear reactors to generate electricity, as the released energy can be harnessed to produce steam, which then drives a turbine to generate electricity.\nNuclear fusion, on the other hand, is the process by which two or more atomic nuclei combine to form a single, heavier nucleus. This process also releases energy, but in this case, the energy is produced through the binding of the nuclei together. Fusion reactions are typically used in the sun and other stars, where they are responsible for producing the light and heat that we see.\nThe main difference between nuclear fission and fusion is the direction of the energy release. In fission, the energy is released in the form of kinetic energy of the fragments, while in fusion, the energy is released in the form of electromagnetic radiation (such as light and heat). Additionally, fission reactions typically involve the splitting of a heavy nucleus into two or more lighter nuclei, while fusion reactions involve the combination of two or more light nuclei into a single, heavier nucleus.\nIn summary, nuclear fission is the process of splitting a heavy nucleus into two or more lighter nuclei, releasing energy in the process, while nuclear fusion is the process of combining two or more light nuclei into a single, heavier nucleus, also releasing energy.'

# %% [markdown]
# We still get the same output as we're not really doing anything differently here, but we have now added **Llama 2 13B Chat** to the LangChain library. Using this we can now begin using LangChain's advanced agent tooling, chains, etc, with **Llama 2**.

# %% [markdown]
# ## Initializing a RetrievalQA Chain

# %% [markdown]
# For **R**etrieval **A**ugmented **G**eneration (RAG) in LangChain we need to initialize either a `RetrievalQA` or `RetrievalQAWithSourcesChain` object. For both of these we need an `llm` (which we have initialized) and a Pinecone index — but initialized within a LangChain vector store object.
#
# Let's begin by initializing the LangChain vector store, we do it like so:

# %%
from langchain.vectorstores import Pinecone

text_field = 'text'  # field in metadata that contains text content

vectorstore = Pinecone(
    index, embed_model.embed_query, text_field
)

# %% [markdown]
# We can confirm this works like so:

# %%
query = 'What is African Horse Sickness (AHS)?'

vectorstore.similarity_search(
    query,  # the search query
    k=3  # returns top 3 most relevant chunks of text
)
# Out:
# [Document(page_content='What is African Horse Sickness (AHS)? African Horse Sickness (AHS) is a non-contagious, vector-borne viral disease.', metadata={'title': 1.0}),
#  Document(page_content='What is the fourth form of AHS? The fourth form of AHS is known as African horse sickness fever and is the mildest form.', metadata={'title': 28.0}),
#  Document(page_content='What are clinical signs of Equine Viral Arteritis in older or immunocompromised horses? Severe clinical signs may include fever, depression, nasal discharge, swelling of limbs, and abortion in pregnant mares.', metadata={'title': 153.0})]

# %% [markdown]
# Looks good! Now we can put our `vectorstore` and `llm` together to create our RAG pipeline.

# %%
from langchain.chains import RetrievalQA

rag_pipeline = RetrievalQA.from_chain_type(
    llm=llm, chain_type='stuff',
    retriever=vectorstore.as_retriever()
)

# %% [markdown]
# Let's begin asking questions! First let's try *without* RAG:

# %%
llm('What is African Horse Sickness (AHS)?')
# Out:
# "\n everybody loves to ride and enjoy their horses, but there are some diseases that can affect them. One of the most common and deadly diseases in Africa is African horse sickness (AHS). It is a viral disease that affects horses, donkeys, and mules. AHS is caused by a virus belonging to the Reoviridae family, which is transmitted through the bite of an infected mosquito. The virus attacks the equine's nervous system, leading to symptoms such as weakness, loss of coordination, difficulty breathing, and eventually death.\nThe disease was first identified in 1957 in South Africa and has since spread throughout much of sub-Saharan Africa. It is particularly prevalent in areas with high temperatures and humidity, where the mosquito population thrives.\nSymptoms of African Horse Sickness:\nThe symptoms of African horse sickness usually appear within 24 to 48 hours after being bitten by an infected mosquito. They include:\nWeakness or loss of coordination\nDifficulty breathing or rapid breathing\nLoss of appetite or depression\nCollapse or coma\nIn severe cases, the disease can progress to paralysis, seizures, and even death.\nDiagnosis of African Horse Sickness:\nDiagnosing African horse sickness can be challenging because the symptoms are similar to those of other diseases. However, a veterinarian may perform several tests to confirm the diagnosis, including:\nBlood tests to detect antibodies against the virus\nNervous system examination to check for signs of neurological damage\nMicroscopic examination of cerebrospinal fluid for evidence of the virus\nPCR (polymerase chain reaction) test to detect the virus genetic material in the blood or cerebrospinal fluid\nTreatment and Prevention of African Horse Sickness:\nUnfortunately, there is no specific treatment for African horse sickness, and the only way to prevent it is through vaccination. Vaccines are available for both horses and humans, and they provide protection against the virus for up to two years.\nVaccination is the most effective way to protect horses from African horse sickness. Vaccination should be"

# %% [markdown]
# Hmm, that's not what we meant... What if we use our RAG pipeline?

# %%
rag_pipeline('What is African Horse Sickness (AHS)?')
# Out:
# {'query': 'What is African Horse Sickness (AHS)?',
#  'result': ' African Horse Sickness (AHS) is a non-contagious, vector-borne viral disease.'}
